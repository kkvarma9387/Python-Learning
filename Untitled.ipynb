# %%
import pandas as pd
json_file = [{"claimID":40769,"lossDate":"2020-03-10T00:00:00","claimDate":"2020-03-10T00:00:00","claimStatus":"Opened","claimAmount":"0.0000","notes":""},{"claimID":40769,"lossDate":"2020-03-10T00:00:00","claimDate":"2020-03-10T00:00:00","claimStatus":"Opened","claimAmount":"0.0000","notes":""},{"claimID":40769,"lossDate":"2020-03-10T00:00:00","claimDate":"2020-03-10T00:00:00","claimStatus":"Opened","claimAmount":"0.0000","notes":""},{"claimID":40769,"lossDate":"2020-03-10T00:00:00","claimDate":"2020-03-10T00:00:00","claimStatus":"Opened","claimAmount":"0.0000","notes":""}]


pd.DataFrame(json_file)
# Out:
#   claimAmount            claimDate  claimID claimStatus             lossDate notes
# 0      0.0000  2020-03-10T00:00:00    40769      Opened  2020-03-10T00:00:00
# 1      0.0000  2020-03-10T00:00:00    40769      Opened  2020-03-10T00:00:00
# 2      0.0000  2020-03-10T00:00:00    40769      Opened  2020-03-10T00:00:00
# 3      0.0000  2020-03-10T00:00:00    40769      Opened  2020-03-10T00:00:00

# %% [markdown]
#  import matplotlib.pyplot as plt
# %matplotlib inline
#
# x = [1,2,3,4,5,6,7]
# y = [23,53,53,23,24,58,29]
# plt.plot(x,y,color='green',marker = '*',markersize=20,alpha =1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = [1,2,3,4,5,6]
y = [51,53,63,56,54,58,29]
#plt.plot(x,y,"g+")

max_t = [34,54,56,23,57,43]
min_t = [ 21,34,45,76,67,78]
avg_t= [32,43,45,67,87,34]

plt.xlabel("Days")
plt.ylabel("Temparature")
plt.title("Weather")
plt.plot(x,max_t,label = "Max")
plt.plot(x,min_t,label ="Min")
plt.plot(x,avg_t,label = "Avg")
plt.legend("best",shadow =True,fontsize= 'small')
plt.grid()

# %%
company = ['Google','Amazon','MAFT',"FB"]
revenue = [45,67,87,34]
profit=[23,5,56,66]

# %%
ypos = np.arange(len(company))

# %%
plt.xticks(ypos,company)

plt.ylabel("Revenue")
plt.title("US tech Stockes")
plt.bar(ypos-0.2,revenue,width = 0.4,label = "Revenue")
plt.bar(ypos+0.2,profit,width = 0.4,label='Profit')
plt.legend()

# %%
blood_suger_men = [140,130,96,144,143,120,110,126,150,57,45,57,43]
blood_suge_women= [123,110,126,138,119,120,110,126,127,138,139,90,99]
plt.hist([blood_suger_men,blood_suge_women],
         bins=[80,100,125,150],rwidth = 0.95,color=["green","orange"],
         label=["Men","Women"],orientation='horizontal')
plt.legend()
plt.title("Blood Sugar")
# Out:
# Text(0.5, 1.0, 'Blood Sugar')

# %%
a = 4
b = 5
a+b
# Out:
# 9

# %%
print(a)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exp_val = [1400,400,800,3900,1000]
exp_dec = ['Market','Food','Phone','RoomRent','Expnes']

# %%
plt.pie(exp_val,labels=exp_dec,radius=1.6,autopct='%0.1f%%',shadow=True,explode=[0,0.1,0.1,0.1,0],startangle=180)
plt.axis("Equal")
plt.show()
